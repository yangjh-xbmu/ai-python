# %%
import mytools

# %%
mytools.dsllm('请扮演pandas教学专家，首先为我介绍pandas，文言文，字数不要太长')
# Out:
# '夫Pandas者，数据分析之利器也，Python库中之翘楚。其以DataFrame为基石，行与列交织，数据之结构井然有序。可读取、清洗、变换、分析数据，功能之强大，操作之便捷，实为数据科学家之良伴。'

# %%
print(mytools.dsllm('请扮演pandas教学专家，介绍pandas的开发者'))
# Out:
# `pandas` 是一个开源的数据处理和分析库，广泛应用于数据科学和数据分析领域。它的开发者是 Wes McKinney。Wes McKinney 是一位著名的软件开发者和技术作家，他在金融行业工作期间，为了更高效地处理和分析金融数据，于2008年创建了 `pandas` 项目。
#
# Wes McKinney 在开发 `pandas` 时，借鉴了 R 语言中的数据框（data frame）概念，并结合了 Python 的灵活性和强大的生态系统，使得 `pandas` 成为数据科学家和分析师的首选工具之一。
#
# 除了 `pandas`，Wes McKinney 还参与了其他一些开源项目，并且撰写了《Python for Data Analysis》一书，该书详细介绍了如何使用 Python 和 `pandas` 进行数据分析。
#
# 总的来说，Wes McKinney 的贡献使得 `pandas` 成为了一个强大且易用的数据处理工具，极大地推动了数据科学领域的发展。

# %%
print(mytools.dsllm('请扮演pandas教学专家，我是一个初学者，基础薄弱，请针对我的情况，列出最快入门的教程大纲'))
# Out:
# 当然！针对你的情况，我会为你设计一个循序渐进、易于理解的Pandas入门教程大纲。这个大纲将帮助你快速掌握Pandas的基本概念和常用操作。
#
# ### 教程大纲
#
# #### 1. **Pandas简介与安装**
#    - 什么是Pandas？
#    - Pandas的主要功能和用途
#    - 安装Pandas（使用pip或conda）
#
# #### 2. **Pandas的基本数据结构**
#    - **Series**：一维数组，类似于带标签的数组
#      - 创建Series
#      - 访问和修改Series中的数据
#      - Series的基本操作（如索引、切片、过滤）
#    - **DataFrame**：二维表格，类似于Excel表格
#      - 创建DataFrame
#      - 访问和修改DataFrame中的数据
#      - DataFrame的基本操作（如索引、切片、过滤）
#
# #### 3. **数据导入与导出**
#    - 从CSV文件导入数据到DataFrame
#    - 从Excel文件导入数据到DataFrame
#    - 从SQL数据库导入数据到DataFrame
#    - 将DataFrame导出为CSV、Excel、SQL等格式
#
# #### 4. **数据清洗与预处理**
#    - 处理缺失值（NaN）
#      - 检测缺失值
#      - 删除缺失值
#      - 填充缺失值
#    - 数据类型转换
#      - 查看和修改数据类型
#      - 字符串操作（如大小写转换、分割、替换）
#    - 重复值处理
#      - 检测重复值
#      - 删除重复值
#
# #### 5. **数据选择与过滤**
#    - 使用标签（Label）进行选择
#    - 使用位置（Position）进行选择
#    - 使用条件进行过滤
#    - 多条件过滤
#
# #### 6. **数据排序与分组**
#    - 按列排序
#    - 按多列排序
#    - 分组操作（GroupBy）
#      - 按单列分组
#      - 按多列分组
# ...

# %%
curriculumContent = '''
#### 1. **Pandas简介与安装**
   - 什么是Pandas？
   - Pandas的主要功能和用途
   - 安装Pandas（使用pip或conda）
'''
prompt = f'''
请扮演pandas教学专家，我是一个初学者，基础薄弱，请就<content>{curriculumContent}</content>教学内容，针对我的情况，生成教学内容。

要求：
1. 每行字数不超过70字
'''
print(mytools.dsllm(prompt))
# Out:
# 好的，我会为你详细介绍Pandas的基础知识，并确保每行字数不超过70字。
#
# #### 1. **Pandas简介与安装**
#
# - **什么是Pandas？**
#   Pandas是一个强大的数据处理和分析库，基于Python。
#   它提供了高效的数据结构和数据分析工具。
#
# - **Pandas的主要功能和用途**
#   Pandas主要用于数据清洗、数据操作和数据分析。
#   它支持多种数据格式，如CSV、Excel、SQL等。
#
# - **安装Pandas（使用pip或conda）**
#   使用pip安装：在终端输入`pip install pandas`。
#   使用conda安装：在终端输入`conda install pandas`。
#
# 希望这些内容对你有帮助！如果有任何问题，欢迎随时提问。

# %%
curriculumContent = '''
#### 2. **Pandas的基本数据结构**
   - **Series**：一维数组，类似于带标签的数组
     - 创建Series
     - 访问和修改Series中的数据
     - Series的基本操作（如索引、切片、过滤）
   - **DataFrame**：二维表格，类似于Excel表格
     - 创建DataFrame
     - 访问和修改DataFrame中的数据
     - DataFrame的基本操作（如索引、切片、过滤）
'''
prompt = f'''
请扮演pandas教学专家，我是一个初学者，基础薄弱，请就教学大纲<content>{curriculumContent}</content>，针对我的情况，生成教学内容。

'''
print(mytools.dsllm(prompt))
# Out:
# ### Pandas教学内容：针对初学者的基础教程
#
# #### 2. **Pandas的基本数据结构**
#
# ##### 2.1 **Series**：一维数组，类似于带标签的数组
#
# ###### 2.1.1 创建Series
#
# 首先，我们需要了解什么是Series。Series是Pandas中的一种基本数据结构，类似于一维数组，但它有一个额外的特性：每个元素都有一个标签（也称为索引）。
#
# ```python
# import pandas as pd
#
# # 创建一个简单的Series
# s = pd.Series([1, 3, 5, 7, 9])
# print(s)
# ```
#
# 输出结果：
#
# ```
# 0    1
# 1    3
# 2    5
# 3    7
# 4    9
# dtype: int64
# ```
#
# 在这个例子中，`0, 1, 2, 3, 4` 是默认的索引，`1, 3, 5, 7, 9` 是Series中的数据。
#
# ###### 2.1.2 访问和修改Series中的数据
#
# 你可以通过索引访问Series中的数据：
#
# ```python
# # 访问第一个元素
# print(s[0])  # 输出: 1
#
# # 访问第三个元素
# print(s[2])  # 输出: 5
# ```
#
# 你也可以通过索引修改Series中的数据：
#
# ```python
# # 修改第一个元素
# s[0] = 10
# print(s)
# ```
#
# 输出结果：
#
# ```
# 0    10
# 1     3
# 2     5
# 3     7
# 4     9
# dtype: int64
# ```
#
# ###### 2.1.3 Series的基本操作（如索引、切片、过滤）
#
# - **索引**：你可以使用标签（索引）来访问Series中的数据。
#
# ```python
# # 创建一个带有自定义索引的Series
# s = pd.Series([1, 3, 5, 7, 9], index=['a', 'b', 'c', 'd', 'e'])
# print(s)
#
# # 访问索引为'c'的元素
# ...

# %%
curriculumContent = '''
#### 2. **Pandas的基本数据结构**
   - **Series**：一维数组，类似于带标签的数组
     - 创建Series
     - 访问和修改Series中的数据
     - Series的基本操作（如索引、切片、过滤）
   - **DataFrame**：二维表格，类似于Excel表格
     - 创建DataFrame
     - 访问和修改DataFrame中的数据
     - DataFrame的基本操作（如索引、切片、过滤）
'''
prompt = f'''
请扮演pandas教学专家，我是一个初学者，基础薄弱，请就教学大纲<content>{curriculumContent}</content>，针对我的情况，生成教学内容。

要求：
1. 教学内容要有趣，我的兴趣是魔兽世界。
2. 教学内容要有练习题，但是不要给出答案。
'''
print(mytools.dsllm(prompt))
# Out:
# ### Pandas教学大纲：魔兽世界版
#
# 欢迎来到Pandas的奇幻世界！今天我们将一起探索Pandas的基本数据结构，就像在魔兽世界中探索未知的领域一样。我们将通过魔兽世界的角色和任务来学习Pandas的`Series`和`DataFrame`，让你在学习的同时也能感受到游戏的乐趣。
#
# #### 1. **Series：一维数组，类似于带标签的数组**
#
# 想象一下，你在魔兽世界中创建了一个新角色，这个角色有各种属性，比如力量、敏捷、智力等。这些属性可以看作是一个`Series`，每个属性都有一个标签（比如“力量”）和一个对应的值（比如10）。
#
# ##### 创建Series
#
# 首先，我们来创建一个`Series`，就像创建一个新角色一样。
#
# ```python
# import pandas as pd
#
# # 创建一个Series，表示角色的属性
# attributes = pd.Series([10, 15, 20], index=['力量', '敏捷', '智力'])
# print(attributes)
# ```
#
# ##### 访问和修改Series中的数据
#
# 你可以通过标签来访问和修改角色的属性。比如，你想知道角色的“力量”属性，或者你想把“敏捷”属性提升到25。
#
# ```python
# # 访问“力量”属性
# print(attributes['力量'])
#
# # 修改“敏捷”属性
# attributes['敏捷'] = 25
# print(attributes)
# ```
#
# ##### Series的基本操作（如索引、切片、过滤）
#
# 在魔兽世界中，你可能需要查看所有属性值大于15的属性。这就像在`Series`中进行过滤操作。
#
# ```python
# # 过滤出属性值大于15的属性
# high_attributes = attributes[attributes > 15]
# print(high_attributes)
# ```
#
# **练习题1：**
#
# 1. 创建一个新的`Series`，表示你最喜欢的魔兽世界职业的属性（比如战士、法师、猎人等）。
# 2. 访问并打印出某个属性的值。
# ...
