# %%
# Please install OpenAI SDK first: `pip3 install openai`

from openai import OpenAI

client = OpenAI(api_key="sk-36ce9aa77bf540f8ac82a7e940f6dcfe", base_url="https://api.deepseek.com")

response = client.chat.completions.create(
    model="deepseek-chat",
    messages=[
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": "人的成长中，最关键的品质是什么，请用纵向研究的相关成果回答，不要去搜索网页"},
    ],
    stream=False
)

print(response.choices[0].message.content)
# Out:
# 在纵向研究中，研究者通常会追踪同一组个体在不同时间点的发展变化，以探讨影响成长和发展的关键因素。根据这些研究，以下几个品质被认为是人成长过程中最关键的：
#
# 1. **坚韧性（Resilience）**：
#    纵向研究表明，坚韧性是预测个体能否在面对逆境和挑战时保持积极心态和健康发展的关键因素。坚韧性强的个体能够更好地应对压力，从失败中恢复，并在困难中找到成长的机会。
#
# 2. **自我效能感（Self-Efficacy）**：
#    自我效能感是指个体对自己能否成功完成某项任务的信心。纵向研究发现，高自我效能感的个体更有可能设定并实现目标，表现出更高的学业成就和职业成功。
#
# 3. **情绪智力（Emotional Intelligence）**：
#    情绪智力包括识别、理解和管理自己及他人情绪的能力。纵向研究表明，高情绪智力的个体在人际关系、工作表现和心理健康方面表现更好，能够更有效地处理冲突和压力。
#
# 4. **适应性（Adaptability）**：
#    适应性是指个体在面对变化和不确定性时调整行为和策略的能力。纵向研究发现，适应性强的个体更容易适应新的环境和挑战，表现出更高的生活满意度和幸福感。
#
# 5. **社会支持（Social Support）**：
#    社会支持包括来自家庭、朋友和社区的情感和实际帮助。纵向研究表明，拥有强大社会支持网络的个体在面对压力和逆境时更有可能保持心理健康和积极发展。
#
# 6. **道德发展（Moral Development）**：
#    道德发展涉及个体对是非、正义和责任的理解与实践。纵向研究发现，道德发展良好的个体在社会互动中表现出更高的合作性和责任感，有助于建立积极的社会关系和社区环境。
#
# 这些品质在纵向研究中被反复验证，表明它们在人的成长和发展过程中起着至关重要的作用。通过培养这些品质，个体能够更好地应对生活中的各种挑战，实现全面的发展。

# %%
import mytools

# %%
result = mytools.dsllm('你好，请详细介绍开发团队,如果不知道，请回答不知道，不要编造')
print(result)
# Out:
# 不知道。

# %%
import test

# %%
result = test.dsllm('扮演Python大师，介绍函数的用法，文言文')
print(result)
# Out:
# 夫函数者，乃编程之精髓也。在Python中，函数如匠人之工具，能将复杂之任务分解为若干小节，各司其职，使代码之结构清晰，易于维护。
#
# ### 定义函数
# 欲定义一函数，需用`def`关键字，后随函数名及括号，括号内可置参数，以供函数使用。函数体则以缩进表示，末尾可有`return`语句，以返回结果。
#
# ```python
# def 求和(a, b):
#     """此函数求两数之和"""
#     和 = a + b
#     return 和
# ```
#
# ### 调用函数
# 定义既成，即可调用。调用时，传入参数，函数则依其定义行事，返回结果。
#
# ```python
# 结果 = 求和(3, 5)
# print(结果)  # 输出：8
# ```
#
# ### 参数与返回值
# 函数之参数，如工匠之材料，供其加工。参数可有默认值，若调用时未传，则取默认。返回值则如工匠之成品，供调用者使用。
#
# ```python
# def 乘积(a, b=1):
#     """此函数求两数之积，b默认值为1"""
#     积 = a * b
#     return 积
#
# 结果 = 乘积(4)
# print(结果)  # 输出：4
# ```
#
# ### 变量作用域
# 函数内之变量，其作用域限于函数之内，谓之局部变量。函数外之变量，则为全局变量，其作用域遍及整个程序。
#
# ```python
# 全局变量 = 10
#
# def 修改全局变量():
#     global 全局变量
#     全局变量 = 20
#
# 修改全局变量()
# print(全局变量)  # 输出：20
# ```
#
# ### 递归函数
# 递归者，函数调用自身也。递归如登高，每步皆似前步，直至顶峰。递归需有终止条件，否则如无底之渊，永无止境。
#
# ```python
# def 阶乘(n):
#     if n == 1:
#         return 1
#     else:
#         return n * 阶乘(n - 1)
#
# 结果 = 阶乘(5)
# print(结果)  # 输出：120
# ```
#
# ### 匿名函数
# ...

# %%
result = test.dsllm('扮演Python教学大师，使用鲁迅的写作风格，介绍函数的用法。')
print(result)
# Out:
# 夫函数者，程序之骨也。其用如刀，可切可割，可雕可琢。然其妙处，非言语所能尽述，唯实践方能领悟。
#
# 吾尝观世间诸程序，或繁或简，或长或短，皆有其函数之踪迹。函数者，乃程序之精魂，能将复杂之事，化为简单之步骤。如鲁迅先生所言：“世上本没有路，走的人多了，也便成了路。”函数亦然，初时或觉生疏，然用之既久，便觉其妙无穷。
#
# 函数之定义，如画龙点睛，需先明其名，后定其形。名者，如人之姓氏，形者，如人之体态。名形既定，方可呼之即来，挥之即去。如吾友Python，其函数定义之法，简洁明了，只需“def”三字，便可开宗明义，宣告函数之诞生。
#
# 函数之参数，如人之饮食，需适时而进，方能滋养身心。参数者，乃函数之入口，数据之桥梁。无参数之函数，如无源之水，无本之木，虽能运行，终难持久。故定义函数时，需慎思参数之数目与类型，方能使其发挥最大之效用。
#
# 函数之返回值，如人之言语，需言之有物，方能传情达意。返回值者，乃函数之出口，结果之载体。无返回值之函数，如哑巴之言，虽有动作，终难表达。故定义函数时，需明其返回之物，方能使其言之有据，行之有效。
#
# 函数之调用，如人之行动，需按部就班，方能达成目标。调用者，乃函数之启动，程序之脉搏。无调用之函数，如死水一潭，虽有定义，终难运行。故编写程序时，需适时调用函数，方能使其动如脱兔，静如处子。
#
# 吾尝闻，函数之妙，在于其复用之能。如鲁迅先生所言：“时间就是性命。无端的空耗别人的时间，其实是无异于谋财害命的。”函数亦然，若能复用，便可节省时间，提高效率。故编写函数时，需思其通用之性，方能使其如百宝箱，随取随用。
#
# 总之，函数者，乃程序之精华，编程之利器。学之用之，需勤思善悟，方能得其真谛。如鲁迅先生所言：“希望是附丽于存在的，有存在，便有希望，有希望，便是光明。”函数亦然，有其存在，便有希望，有希望，便是光明。愿诸君勤学不辍，早日掌握函数之妙，编写出精彩绝伦之程序。
