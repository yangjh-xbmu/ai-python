# %%
import mytools

# %%
学习内容 = '''
###### 2.1.2 访问和修改Series中的数据

你可以通过索引访问Series中的数据：<content>

```python
# 访问第一个元素
print(s[0])  # 输出: 1

# 访问第三个元素
print(s[2])  # 输出: 5
```

你也可以通过索引修改Series中的数据：

```python
# 修改第一个元素
s[0] = 10
print(s)
```

输出结果：

```
0    10
1     3
2     5
3     7
4     9
dtype: int64
```


'''

提示词 = f'''
请扮演教学专家，能熟练应用各种学习相关的理论。

请根据【卡片格式资料】，为【学习内容】<content>{学习内容}</content>生成 Anki 学习卡片。

卡片格式资料：


Anki for VSCode splits cards by ## headline. For example, below markdown will generate 2 cards where headlines will be on the front side and its description - on the back.

## What's the Markdown?

Markdown is a lightweight markup language with plain-text-formatting syntax.
Its design allows it to be converted to many output formats,
but the original tool by the same name only supports HTML.

## Who created Markdown?

John Gruber created the Markdown language in 2004 in collaboration with
Aaron Swartz on the syntax.


要求：

1. 每张卡片只有一个主要知识点
'''

# %%
result = mytools.dsllm(提示词)
with open("output.md", "w",encoding='UTF-8') as file:
    # 将Markdown内容写入文件
    file.write(result)
print(result)
# Out:
# ## 如何访问Series中的数据？
#
# 你可以通过索引访问Series中的数据：
#
# ```python
# # 访问第一个元素
# print(s[0])  # 输出: 1
#
# # 访问第三个元素
# print(s[2])  # 输出: 5
# ```
#
# ## 如何修改Series中的数据？
#
# 你也可以通过索引修改Series中的数据：
#
# ```python
# # 修改第一个元素
# s[0] = 10
# print(s)
# ```
#
# 输出结果：
#
# ```
# 0    10
# 1     3
# 2     5
# 3     7
# 4     9
# dtype: int64
# ```

# %%
中文内容 = '制作卡片'
提示词 = f'''
请扮演地道美国人，将{中文内容}翻译成英语，给出音标、例句
'''

print(mytools.dsllm(提示词))
# Out:
# 制作卡片可以翻译为 "make a card"。
#
# 音标：/meɪk ə kɑrd/
#
# 例句：
# - "I want to make a card for my friend's birthday."
#   （我想为朋友的生日制作一张卡片。）
# - "She spent the afternoon making cards for the holidays."
#   （她花了一个下午为节日制作卡片。）

# %%
def fy(中文内容):
    中文内容 = 中文内容
    提示词 = f'''
    请扮演地道美国人，将{中文内容}翻译成英语，给出音标、例句
    '''
    result = mytools.dsllm(提示词)
    print(result)
    return result

# %%
mytools.translate('制作卡片')
# Out:
# 制作卡片
#
# **Translation:** Make a card
#
# **Phonetic Transcription:** /meɪk ə kɑrd/
#
# **Example Sentence:**
# - "I want to **make a card** for my friend's birthday."
#   - 我想为朋友的生日**制作卡片**。
#
# **Explanation:**
# - "Make a card" is a straightforward translation of "制作卡片." The phrase is commonly used in English to describe the act of creating a greeting card or any kind of card. The phonetic transcription helps with pronunciation, where "make" is pronounced as /meɪk/ and "card" as /kɑrd/.
# '制作卡片\n\n**Translation:** Make a card\n\n**Phonetic Transcription:** /meɪk ə kɑrd/\n\n**Example Sentence:** \n- "I want to **make a card** for my friend\'s birthday."\n  - 我想为朋友的生日**制作卡片**。\n\n**Explanation:** \n- "Make a card" is a straightforward translation of "制作卡片." The phrase is commonly used in English to describe the act of creating a greeting card or any kind of card. The phonetic transcription helps with pronunciation, where "make" is pronounced as /meɪk/ and "card" as /kɑrd/.'

# %%
def genAnkiCard(学习内容,文件名称):
    学习内容 = 学习内容
    提示词 = f'''
    请扮演教学专家，能熟练应用各种学习相关的理论。

    请根据【卡片格式资料】，为【学习内容】{学习内容}</content>生成 Anki for VSCode 学习卡片。

    卡片格式资料：


    Anki for VSCode splits cards by ## headline. For example, below markdown will generate 2 cards where headlines will be on the front side and its description - on the back.

    ## What's the Markdown?

    Markdown is a lightweight markup language with plain-text-formatting syntax.
    Its design allows it to be converted to many output formats,
    but the original tool by the same name only supports HTML.

    ## Who created Markdown?

    John Gruber created the Markdown language in 2004 in collaboration with
    Aaron Swartz on the syntax.


    要求：

    1. 每张卡片只有一个主要知识点
    '''
    result = mytools.dsllm(提示词)
    with open(文件名称, "w",encoding='UTF-8') as file:
        # 将Markdown内容写入文件
        file.write(result)
    print(result)

# %%
import mytools
学习内容 = mytools.openFile('pandas数据结构.md')
mytools.render(mytools.genAnkiCard(学习内容,'学习卡片3.md'))
# Out:
# ## 什么是Series？
#
# Series是Pandas中的一种基本数据结构，类似于一维数组，但它有一个额外的特性：每个元素都有一个标签（也称为索引）。
#
# ## 如何创建一个简单的Series？
#
# ```python
# import pandas as pd
#
# # 创建一个简单的Series
# s = pd.Series([1, 3, 5, 7, 9])
# print(s)
# ```
#
# 输出结果：
#
# ```
# 0    1
# 1    3
# 2    5
# 3    7
# 4    9
# dtype: int64
# ```
#
# ## 如何访问和修改Series中的数据？
#
# 你可以通过索引访问Series中的数据：
#
# ```python
# # 访问第一个元素
# print(s[0])  # 输出: 1
#
# # 访问第三个元素
# print(s[2])  # 输出: 5
# ```
#
# 你也可以通过索引修改Series中的数据：
#
# ```python
# # 修改第一个元素
# s[0] = 10
# print(s)
# ```
#
# 输出结果：
#
# ```
# 0    10
# 1     3
# 2     5
# 3     7
# 4     9
# dtype: int64
# ```
#
# ## 如何使用自定义索引创建Series？
#
# ```python
# # 创建一个带有自定义索引的Series
# s = pd.Series([1, 3, 5, 7, 9], index=['a', 'b', 'c', 'd', 'e'])
# print(s)
#
# # 访问索引为'c'的元素
# print(s['c'])  # 输出: 5
# ```
#
# ## 如何对Series进行切片操作？
#
# ```python
# # 获取索引为'b'到'd'之间的元素
# print(s['b':'d'])
# ```
#
# 输出结果：
#
# ```
# b    3
# c    5
# d    7
# dtype: int64
# ```
#
# ## 如何对Series进行过滤操作？
#
# ```python
# # 获取大于5的元素
# print(s[s > 5])
# ```
#
# 输出结果：
#
# ```
# d    7
# e    9
# dtype: int64
# ```
#
# ## 什么是DataFrame？
#
# DataFrame是Pandas中另一种基本数据结构，类似于二维表格，可以看作是Series的集合。
#
# ## 如何创建一个简单的DataFrame？
#
# ```python
# # 创建一个简单的DataFrame
# data = {
#     'Name': ['Alice', 'Bob', 'Charlie'],
#     'Age': [25, 30, 35],
#     'City': ['New York', 'Los Angeles', 'Chicago']
# }
# df = pd.DataFrame(data)
# print(df)
# ```
#
# 输出结果：
#
# ```
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# ```
#
# ## 如何访问和修改DataFrame中的数据？
#
# 你可以通过列名访问DataFrame中的数据：
#
# ```python
# # 访问'Name'列
# print(df['Name'])
# ```
#
# 输出结果：
#
# ```
# 0      Alice
# 1        Bob
# 2    Charlie
# Name: Name, dtype: object
# ```
#
# 你也可以通过行索引访问DataFrame中的数据：
#
# ```python
# # 访问第一行
# print(df.loc[0])
# ```
#
# 输出结果：
#
# ```
# Name        Alice
# Age            25
# City     New York
# Name: 0, dtype: object
# ```
#
# 你还可以修改DataFrame中的数据：
#
# ```python
# # 修改'Age'列的第一个元素
# df.loc[0, 'Age'] = 26
# print(df)
# ```
#
# 输出结果：
#
# ```
#       Name  Age         City
# 0    Alice   26     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# ```
#
# ## 如何对DataFrame进行切片操作？
#
# ```python
# # 获取前两行
# print(df.loc[0:1])
# ```
#
# 输出结果：
#
# ```
#     Name  Age         City
# 0  Alice   26     New York
# 1    Bob   30  Los Angeles
# ```
#
# ## 如何对DataFrame进行过滤操作？
#
# ```python
# # 获取年龄大于30的行
# print(df[df['Age'] > 30])
# ```
#
# 输出结果：
#
# ```
#       Name  Age     City
# 2  Charlie   35  Chicago
# ```

# %%
import mytools

# %%
mytools.render(mytools.cognitive_load_explain('异步'))
# Out:
# <link rel="stylesheet" href="githubTheme.css">
#
# ### 异步的概念解释
#
# 异步（Asynchronous）是编程中的一个重要概念，特别是在处理需要等待的任务时。为了让你更好地理解，我们可以用一个生活中的例子来类比。
#
# #### 生活中的例子
#
# 想象你正在做饭，但你还需要去洗衣服。通常情况下，你会先做完饭再去洗衣服，或者先洗完衣服再做饭。这就是**同步**的方式，你一次只做一件事。
#
# 但如果你有一个洗衣机，它可以在你做饭的时候自动洗衣服，这样你就不用等洗衣服完成后再去做饭。你可以在做饭的同时，让洗衣机自动完成洗衣服的任务。这就是**异步**的方式，你可以在做一件事的同时，让另一件事自动进行。
#
# #### 编程中的异步
#
# 在编程中，异步的概念类似。假设你有一个程序需要从网上下载一个大文件，同时还要处理用户的输入。如果使用同步的方式，程序会先下载完文件，然后再处理用户的输入。这样用户可能会感到卡顿，因为程序在等待下载完成。
#
# 但如果使用异步的方式，程序可以在下载文件的同时，继续处理用户的输入。下载文件的任务会在后台自动进行，不会阻塞程序的其他部分。这样用户就不会感到卡顿，程序的响应速度也会更快。
#
# ### 测试题
#
# 1. **选择题**：在编程中，异步的主要目的是什么？
#    - A. 让程序运行得更快
#    - B. 让程序在等待某些任务完成时，仍然可以继续执行其他任务
#    - C. 让程序更容易调试
#    - D. 让程序占用更多的内存
#
# 2. **简答题**：请用生活中的一个例子，解释什么是异步。
#
# 希望这个解释对你有帮助！如果你有更多问题，随时问我。

# %%
import mytools
mytools.render(mytools.translate('汉字'))
# Out:
# 以下是将“汉字”翻译成英语，并附上音标和例句的Markdown表格：
#
# | 中文 | 英文 | 音标 | 例句 |
# |------|------|------|------|
# | 汉字 | Chinese characters | /tʃaɪˈniːz ˈkærəktərz/ | The Chinese language is written using Chinese characters. |
#
# 解释：
# - "汉字" 是中文的书写系统，由单个字符组成，每个字符代表一个音节或一个概念。
# - 音标部分 `/tʃaɪˈniːz ˈkærəktərz/` 表示 "Chinese characters" 的发音。
# - 例句 "The Chinese language is written using Chinese characters." 说明了汉字在中文书写中的使用。
